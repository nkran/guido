# %%
from pyfaidx import Sequence, Fasta

# %%
import tempfile
import subprocess
from io import StringIO
import pandas as pd
from shutil import which

from pathlib import Path
from typing import List, Dict, Tuple, Union, Optional

from guido.guides import Guide
from guido.helpers import rev_comp

def run_bowtie(
    guides: List[Guide],
    pam: str = 'NGG',
    core_length: int = 10,
    core_mismatches: int = 0,
    total_mismatches: int = 4,
    genome_index_path: str = '/Users/nace/imperial/guide_tool/guido/tests/data/AgamP4.12',
    threads: int = 1,
    bowtie_path: str = "bin/bowtie/",
) -> tuple:

    pam_mismatches = rev_comp(pam).count('N')
    print(pam_mismatches)
    pam_length = len(pam)

    with tempfile.NamedTemporaryFile(mode="w+t", prefix="guido_") as temp:
        temp.write(
            "\n".join(
                [(f">{i}|{G.guide_chrom}|{G.guide_start}|{G.guide_end}|"
                  f"{G.guide_seq}|{G.guide_strand}"
                  f"\n{rev_comp(G.guide_seq)}")
                  for i, G in enumerate(guides)]
            )
        )
        temp.flush()
    
        if (core_mismatches + pam_mismatches) > 3:
            raise ValueError('The value for the parameter coreMismatches is not valid: ' + str(core_mismatches))
        if core_mismatches > total_mismatches:
                raise ValueError('The value for coreMismatches cannot be greater than totalMismatches:' + str(core_mismatches) + ">" + str(total_mismatches))

    
        bowtie_command = (f"{bowtie_path}bowtie -p {threads} --quiet -y "
                        f"-n {core_mismatches + pam_mismatches} "
                        f"-l {core_length + pam_length} "
                        f"-e {(total_mismatches * 30) + 30 } -a "
                        f"-x {genome_index_path} "
                        f"-f {temp.name}")

        print(bowtie_command)
        
        rproc = subprocess.Popen(
            bowtie_command.split(),
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            universal_newlines=True,
        )
        
        stdout, stderr = rproc.communicate()

        with open('/Users/nace/imperial/guide_tool/guido.bowtie.txt', 'w') as b:
            b.write(stdout)

    return stdout, stderr

def parse_mismatches(mismatches, strand, seq_len):
    mm_split = mismatches.split(',')
    mm_dict = {}
    if len(mm_split) > 1:
        for m in mm_split:
            pos, c = m.split(':')
            c = c.split('>')

            if strand == '-':
                mm_dict[seq_len-int(pos)] = rev_comp(c[0])
            else:
                mm_dict[seq_len-int(pos)] = c[0]
    return mm_dict

def hit_is_valid(mismatches, non_arbitrary_positions):
    return all([False if pos in non_arbitrary_positions else True for pos in mismatches.keys()])

def parse_bowtie_output(out: str, pam='NGG'):

    non_arbitrary_positions = [21 + ix for ix, nucl in enumerate(pam) if nucl in ['A', 'T', 'G', 'C']]
    
    for line in out.split('\n'):
        cols = line.split('\t')
        if len(cols) > 1:
            ix, g_chrom, g_start, g_end, g_seq, g_strand = cols[0].split('|')
            t_strand, t_chrom, t_start, t_seq, _, t_rep, t_mismatches = cols[1:]
            
            if t_strand == '-':
                t_strand = '+'
            else:
                t_seq = rev_comp(t_seq)
                t_strand = '-'

            if g_chrom == t_chrom and int(g_start) == (int(t_start) + 1):
                print('------')
                print(t_seq, t_strand, cols)
                pass
            else:
                mismatches = parse_mismatches(t_mismatches, t_strand, len(t_seq))
                if hit_is_valid(mismatches, non_arbitrary_positions):
                    mm_string = ''.join([mismatches[i+1] if (i+1) in mismatches.keys() 
                                            else "." for i, _ in enumerate(g_seq)])

                    print(mm_string, hit_is_valid(mismatches, non_arbitrary_positions),)


out, err = run_bowtie_f(l.guides, core_mismatches=2, core_length=10, total_mismatches=4)
parse_bowtie_output(out)
# Out:
# 1
# bin/bowtie/bowtie -p 1 --quiet -y -n 3 -l 13 -e 150 -a -x /Users/nace/imperial/guide_tool/guido/tests/data/AgamP4.12 -f /var/folders/vk/qp7qjq952h19zhsbv1b17vc80000gn/T/guido_spj545ob
# ------
# CCGTGCGTCCAGAGCGTTCGAGG + ['0|2R|48714149|48714172|CCGTGCGTCCAGAGCGTTCGAGG|+', '-', '2R', '48714148', 'CCGTGCGTCCAGAGCGTTCGAGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# .T.G...G...A........... True
# G..G....A.C.C.......... True
# G..A....ATC............ True
# ...A.G..G...C.A........ True
# .G..A.AG......T........ True
# AG.......T.........TT.. True
# T.CA............CC..... True
# .G.....G....C.T..A..... True
# ...A.....A.A....A.A.... True
# .......A.A.A.A....G.... True
# .......A.A.TG.......G.. True
# T...T......C.T......G.. True
# .G...A.......T...C..G.. True
# ...A....A..T.....A..G.. True
# .T..AA..G.........G.... True
# .T..AA..G.........G.... True
# .G...............C.C... True
# .T..C............G.AC.. True
# T..C....A.C......A..... True
# ...G..A.T...G....A..... True
# .A...T......T.....GT... True
# ...AC..A.....T.....A... True
# ........T....T.C....C.. True
# .G.....A......T...G.C.. True
# .....T.C.T.....A....G.. True
# .G.G....G....T......T.. True
# ------
# GAGCAACGACCACCTGCTCTAGG + ['1|2R|48714171|48714194|GAGCAACGACCACCTGCTCTAGG|+', '-', '2R', '48714170', 'GAGCAACGACCACCTGCTCTAGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# ...G..T.G...G.A........ True
# ..A.T...T.A....T....... True
# ....TT.TG.........T.... True
# .CA..C...........GT.... True
# C.T..T....A........A... True
# .....C.A......G...GA... True
# ....G.G..A..A......G... True
# ..T....C...G....A..G... True
# ..C......G.T...C...C... True
# .T......C.........ACT.. True
# .C.......GT.......GA... True
# C....T.A....G......G... True
# C.T.......G.....A...C.. True
# .....G..G..G.......GC.. True
# .....G..G..G.......GC.. True
# ....C...G.....C....CC.. True
# ------
# TGTTTTCTGTGTGTGTGTACAGG + ['2|2R|48714220|48714243|TGTTTTCTGTGTGTGTGTACAGG|+', '-', '2R', '48714219', 'TGTTTTCTGTGTGTGTGTACAGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# GTG...G................ True
# G...G.G................ True
# GCG.G.G................ True
# CTG.G.G................ True
# GTG.G.G................ True
# GTG.G.G................ True
# CAC.G.G................ True
# A.CGG.G................ True
# GTG..CG................ True
# GTG.G.A................ True
# GTA.G.A................ True
# AT..G.G..A............. True
# ...A.C...CAA........... True
# .CG..GG.....T.......... True
# .TG.G.T.....T.......... True
# ..C.C.TC....A.......... True
# .A.G..G......C......... True
# .C.......AC.TC......... True
# ATG.G.........C........ True
# .TC..G.......CT........ True
# ACG.....C......C....... True
# ......T.T...C..G....... True
# GC..GC................. True
# ...ACC................. True
# .TA.A.G................ True
# ATG.G.G................ True
# GTG.G.G................ True
# GTG.G.G................ True
# GTG.G.G................ True
# GT.G.GG................ True
# .C....T................ True
# A....GG...T............ True
# ...G.AG...A............ True
# .....AG.T.A.C.......... True
# .TC..G.......CT........ True
# .C..G.G.....A.C........ True
# GT..G.G........C....... True
# ...GG.G.............C.. True
# ....G.G.............T.. True
# .T.G...C............T.. True
# C.CAC...............G.. True
# GT..G.G.............G.. True
# .AG.G.G.............G.. True
# .TG.G.G.............G.. True
# .A.AA.G.............G.. True
# C..AG.A.............G.. True
# ..G.A.G............T... True
# C.CA..T............T... True
# .TG...G............TG.. True
# .T..G.A............TG.. True
# ....G.GG...........TG.. True
# A.G.A..............A... True
# .T....T............AC.. True
# G...G.G............AG.. True
# CT...G.............G... True
# GT..G.G............G... True
# .TA.G.G............G... True
# GA....G..C.........G... True
# ..C....GT..........GC.. True
# ..AAA.............G.... True
# A...G.G...........G.... True
# .T..G.G...........G.... True
# A.G.G.G...........G.... True
# G.G.G.G...........G.... True
# .TG.G.G...........G.... True
# .AG.G.G...........G.... True
# G.C.G.G...........G.... True
# ..CA.G..T.........G.... True
# .T..G.G..A........G.... True
# .T....T.CA........G.... True
# .TG.A.............G.C.. True
# G...G.G...........G.C.. True
# .T....T.T.........G.C.. True
# G...GG............G.G.. True
# ...GCA............G.G.. True
# G.....G...........G.G.. True
# AC....G...........G.G.. True
# GT....G...........G.G.. True
# ..G.G.G...........G.G.. True
# ..G.G.G...........G.G.. True
# GT....G...........G.T.. True
# ...AC.G...........G.T.. True
# GT....T...........G.T.. True
# .T....T.T.........G.T.. True
# GTG...............GT... True
# .T..CC............GT... True
# AA....G...........GT... True
# C...G.A...........GT... True
# .C..A.A...........GT... True
# A.C...T...........GT... True
# C...A..A..........GT... True
# .T....T.T.........GT... True
# G...G.............GTG.. True
# ...A.A............GTG.. True
# ....C.G...........GTG.. True
# C........G........GTG.. True
# .CG...............GTT.. True
# .T....T...........GTT.. True
# ...G..T...........GTT.. True
# ...A..G...........GTT.. True
# .....CG...........GTT.. True
# ..G.G.G...........GA... True
# .T..C.G...........GA... True
# .T....T.T.........GA... True
# ......GA..........GAC.. True
# ...G..............GAT.. True
# A...G.............GAT.. True
# .A..G.G...........GG... True
# .A..G.G...........GG... True
# ..C...T...........GGG.. True
# ......GC..........GGG.. True
# C.....G...........GGC.. True
# .A....G...........GGT.. True
# ....A.G...........GGT.. True
# ...GC..GA.........T.... True
# ..G.A.A...........T.T.. True
# ...A..T...........T.T.. True
# .T..C.G...........TT... True
# ..A...............TTT.. True
# ...G..G...........TTT.. True
# ....G.G...........TTT.. True
# G.....T...........TG... True
# ...CG.G...........TA... True
# ....A.G..........A.GT.. True
# ......G..........AG.T.. True
# ......A..A.......AC.... True
# G...G.G..........G..C.. True
# .C...C.A.........G.G... True
# ..G.G............G.GG.. True
# .T..G.G..........GT.... True
# ..GGG.G..........C..... True
# .C.AC.G..........C..... True
# .A...GG..........C.G... True
# ATC.C...........A...... True
# ..CA.G..........A...G.. True
# .TC.G.G.........T...... True
# ....G.G.........T..T... True
# ...G..T.........T..TG.. True
# G.....G.........T..GG.. True
# ..G...G.........T.G.C.. True
# ..G...T.........T.GG... True
# GA..G...........T.C.... True
# G.....G.........T.C.... True
# .TG...G.........TG..... True
# ....G.G.........C...... True
# ......AGC.......C.C.... True
# ..C...T...A......A..... True
# ...C......TG.....A..... True
# ..GG...........GTA..... True
# ..GG...........GTA..... True
# A.....A.A...A....G..... True
# .T....T.....A..G.G..... True
# ....GA...C..T.....G.... True
# ...G.A....C...C...G.... True
# ..A...G..C....T...G.... True
# ....C......G..T...G.... True
# C......C.....CT...G.... True
# C......C.....CT...G.... True
# C......C.....CT...G.... True
# ....G.G....A....A.G.... True
# ......T...C.......C.... True
# ...G.....C.A......C.... True
# .T..C.G........G..C.... True
# C....G....T......CC.... True
# ..G.G..........A.CC.... True
# ..G..C.A....T.....T.... True
# C..C..T...A........A... True
# ..C...T.T..C.......A... True
# C.....G..C...C.....A... True
# ..C....C..C...C....A... True
# ......G.......T....A... True
# CT............T..C.A... True
# ......T.T.C.......CA... True
# ....G.G.......T...GA... True
# .....G..C......G.G.G... True
# ...G..G.......T...TG... True
# C.....T........G..TG... True
# ..G.G.G.....A......T... True
# .TG...G......A.....T... True
# .T....T........C...T... True
# .A.............G.A.T... True
# G.....G.....C.....TT... True
# ...C....A.....A...GT... True
# ....G.G.......C...GT... True
# CA....G.......A.....T.. True
# ...A.....C..C.A.....T.. True
# ....G.G......G...A..T.. True
# ......T.T.T.......G.T.. True
# ..C...A...TC........G.. True
# C...C.....A....A....G.. True
# ....G.G.......T..C..G.. True
# ..G.G.G...T.........C.. True
# ....C.G....AA.......C.. True
# ...G.A.G.....G......C.. True
# .C.....C.....C....G.C.. True
# A....G......T......AC.. True
# A....G......T......AC.. True
# A....G......T......AC.. True
# .AAAA...............T.. True
# ..CG..TG............T.. True
# .TG.G...............C.. True
# .TG.G.G.............C.. True
# ..G.GGT.............C.. True
# C.CGC...............G.. True
# ...A..G.............G.. True
# C.G.G.G.............G.. True
# G....A.AA..........T... True
# A.....A..A.........T... True
# .T.................TG.. True
# ..G.A.G............TG.. True
# ....GC.............TT.. True
# ....G.G............TT.. True
# .C....T............TT.. True
# ...G..T............TC.. True
# CT..G.G............G... True
# .TC.G.G............G... True
# GT....T............G... True
# ....G.G..C.........GT.. True
# ..G..C.G...........GG.. True
# AA..G.G............A... True
# C.....T............A... True
# CC....T............A... True
# .TG.....C..........AG.. True
# .T.G..G............AT.. True
# .T..G.G............AT.. True
# ....G.G............AC.. True
# .T...G............T.... True
# ..GGG.G...........T.... True
# ..G.G.G...........T.G.. True
# .T....T...........T.G.. True
# ..A.G.A...........T.G.. True
# ...G.GG...........TG... True
# .C...C.G..........TG... True
# G.....G...........TGC.. True
# .T....T...........TGC.. True
# ..G...G...........TGT.. True
# ....A.G...........TGT.. True
# .T....G...........TTT.. True
# .T..G.............TTG.. True
# .C..G.............TTG.. True
# GTG.G.............G.... True
# C.G.GA............G.... True
# CT....G...........G.... True
# C.C...G...........G.... True
# .T..G.G...........G.... True
# GT..G.G...........G.... True
# CC..G.G...........G.... True
# ..G.G.G...........G.... True
# G...GCG...........G.... True
# .T..GGG...........G.... True
# G...G.AG..........G.... True
# GT..G.............G.C.. True
# .TG...T...........G.C.. True
# G.C.G.............G.G.. True
# CT....G...........G.G.. True
# ....G.G...........G.G.. True
# C...G.G...........G.G.. True
# ..C.G.G...........G.G.. True
# ..A.G.G...........G.G.. True
# ....A.A...........G.G.. True
# ....G.G..C........G.G.. True
# C.....G..G........G.G.. True
# .T..G.G...........G.T.. True
# ..G.G.G...........G.T.. True
# ..G.G.G...........G.T.. True
# C...G.G...........GT... True
# ....G.AA..........GT... True
# ..G..C.G..........GT... True
# .T....T.T.........GT... True
# CA................GTG.. True
# ......G...........GTG.. True
# C.....G...........GTG.. True
# ...C..G...........GTG.. True
# .T....A...........GTG.. True
# ....C.A...........GTG.. True
# .....GA...........GTG.. True
# .....GA...........GTG.. True
# ...G....T.........GTG.. True
# ..G.G.............GTT.. True
# ..G.G.............GTT.. True
# .C....G...........GTT.. True
# .T....G...........GTT.. True
# ....G.G...........GTT.. True
# ....G.G...........GTT.. True
# ..A....G..........GTT.. True
# A.....G...........GTC.. True
# ......T...........GG... True
# ....G.G..C........GG... True
# ......G...........GGC.. True
# ..C...............GGG.. True
# G.....G...........GGG.. True
# C....GG...........GA... True
# ...G..G...........GAT.. True
# ..G.G.G...........C.G.. True
# ...G.C............CG... True
# G.....G...........CTG.. True
# ..C...T...........CTT.. True
# .C.C...A.........C..... True
# .AGC.............C..C.. True
# G...G.T..........C.T... True
# ...G.A...........C.TC.. True
# .T..G.G..........C.A... True
# .TG.G............C.G... True
# ...G..T..........CG.C.. True
# C.G.G.A..........G..... True
# ..CGC..A.........G..... True
# .A....G..........G.TT.. True
# G...A.T.T.......T...... True
# ...G.GT.........T.G.... True
# ...G..G.A.......T.G.... True
# ...A.....C......T.C.G.. True
# ..C.G...........A..TG.. True
# .T....G.........A..TG.. True
# ...CGA...G......C...... True
# ...CGA...G......C...... True
# ...C..G.........C..TG.. True
# C.C.G...........C.T.... True
# .T....G.........C.T.T.. True
# ....A.G.........C.TA... True
# ...G.GA.........C.C.... True
# .T....T.A....C..A...... True
# .C..G...T.....C.C...... True
# ..C..GG...A......C..... True
# ....C.G...T.A....C..... True
# ...A.C........A.TG..... True
# ....G.T....GA.....G.... True
# C....C..C...T.....G.... True
# CT.C.........A....G.... True
# ...G..G.......TG..G.... True
# ......G.A.A......GG.... True
# .....GG......A.G..T.... True
# .....G.C...A....C.T.... True
# GT....G.....T.....C.... True
# .T....G.....C......G... True
# ...C..T.T.....A....G... True
# ..A.....C.T.....T..G... True
# ..CC.........A....TG... True
# .T....T...A.......GG... True
# C..G..T....A.......A... True
# .T....G.T...T......A... True
# ....GCG.....A......A... True
# ......AA..T.A......A... True
# .T.G.G......C......A... True
# .CG...G.......A....A... True
# ......T.....C....A.A... True
# .T...GT....A.......T... True
# .CA.......A......A.T... True
# G......G......T..A.T... True
# G.A.....T.T.........C.. True
# ..G.G.G.....C.......C.. True
# C.....T.......C.T...C.. True
# C.....T.......C.T...C.. True
# A....G......T......AC.. True
# A....G......T......AC.. True
# A....G......T......AC.. True
# A....G......T......AC.. True
# ....G.G.......T....AC.. True
# A....AT...T.........G.. True
# ..G.G.G...C.........G.. True
# ...G.A......A.......G.. True
# ....A...A..C...A....G.. True
# ....CC.A.......C....G.. True
# ..C.G.....C........TG.. True
# ....G.A...T........TG.. True
# ...G..G..AT.........T.. True
# .T....G.....A.......T.. True
# G......G......C..A..T.. True
# .A....T...T.......G.T.. True
# ..C.A.......T.....G.T.. True
# ......G...C........TT.. True
# .T....G......C.....TT.. True
# .T....G........A...GT.. True
# ------
# TGTACAGGCCGTTTCTTGAACGG + ['3|2R|48714235|48714258|TGTACAGGCCGTTTCTTGAACGG|+', '-', '2R', '48714234', 'TGTACAGGCCGTTTCTTGAACGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# .....G.TT.CC........... True
# .T....C...A...TA....... True
# ..GC...C.A...G......... True
# CT....C..A....T........ True
# .AA...T.....G.T........ True
# ..A..G..T...A..C....... True
# ..GG....TT......G...... True
# ..G.....TT.....GG...... True
# .TC...........A.CC..... True
# ...T.C...T...G.....T... True
# ...C.T.....C........A.. True
# ...C...C..A....G....A.. True
# .A..GT.T............T.. True
# A.....CA.........TC.... True
# .C......A.TC....C...... True
# .....TT.......AA.A..... True
# CT........T...T..T..... True
# ........AAC...A...T.... True
# C....C...G..G......G... True
# ...T.....T...G..C..T... True
# ------
# GTACAGGCCGTTTCTTGAACGGG + ['4|2R|48714236|48714259|GTACAGGCCGTTTCTTGAACGGG|+', '-', '2R', '48714235', 'GTACAGGCCGTTTCTTGAACGGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# ...A.ACAT.............. True
# CC..GA....C............ True
# ....G..G.T...GG........ True
# .GC...C.A...G.......... True
# .A.T...G.T.......T..... True
# .......TAC......C...T.. True
# ..T.C.T.........C...C.. True
# .C....C......T.C..C.... True
# ..C...C..A....G....A... True
# ...A..TG......C.....C.. True
# C.....C.......A.....A.. True
# A..GT.T............T... True
# T........T...T..T...... True
# T......A.T...T..T...... True
# ....T....A.G.T..T...... True
# .....A..AT..C....T..... True
# .A..T..T...G.......A... True
# ........GCA.........T.. True
# C.....C.......A.....A.. True
# ------
# TCGCCCTCCCCCCGAGACGCCGG + ['5|2R|48714307|48714330|TCGCCCTCCCCCCGAGACGCCGG|+', '-', '2R', '48714306', 'TCGCCCTCCCCCCGAGACGCCGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# ....G.GT..T...G........ True
# A...G.G.T......C....... True
# ......G..AT..AG........ True
# .GCA..........GC....... True
# C...............TGT.... True
# .G.....T...T..G.C...... True
# G.......G...A.C.C...... True
# ....A..G.....TC.C...... True
# .TC...G.......T.C...... True
# G......T..G....AC...... True
# C.C..........C.TC...... True
# C.C..........C.TC...... True
# C.C..........C.TC...... True
# C.C..........C.TC...... True
# C.T..........C.TC...... True
# C.T..........C.TC...... True
# C.T..........C.TC...... True
# C.T..........C.TC...... True
# C.T..........C.TC...... True
# C.T..........C.TC...... True
# A.T..........C.TC...... True
# C.....C......C.TC...... True
# GA.T.........C....C.... True
# ..C...C......C.C..C.... True
# ..C.G.....A.....C.A.... True
# G.C.A.....T........A... True
# ....TT.T...A........A.. True
# ..C.............TA..T.. True
# G.T.............GG..... True
# G.....A....T....G...... True
# ..A..G..A...G...C...... True
# G..A.A........T.C...... True
# C.C..........C.TC...... True
# C.C..........C.TC...... True
# C.C..........C.TC...... True
# C.C..........C.TC...... True
# C.C..........C.TC...... True
# C.C..........C.TC...... True
# ..C...C......C.TC...... True
# ..T..T.......A.TC...... True
# ..T..T.......A.TC...... True
# ..T..T.......A.TC...... True
# ..T..T.......A.TC...... True
# ..T..T.......A.TC...... True
# ......CAG.....G...T.... True
# ..A..G...A....G...C.... True
# ..CG..........C.C.C.... True
# ..C......A....CT..A.... True
# ..C.G.....A.....C.A.... True
# C.C..........T.C....A.. True
# ------
# CGCACCGCACCAGTGCAGCTAGG + ['6|2R|48714331|48714354|CGCACCGCACCAGTGCAGCTAGG|+', '-', '2R', '48714330', 'CGCACCGCACCAGTGCAGCTAGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# T......TG..T........... True
# A....A...A.CC.......... True
# .T....A..AG...T........ True
# .T.TA...............T.. True
# TCA......G.........A... True
# T.....T.GG.........G... True
# A.G.G..............GG.. True
# T....A.TG.........G.... True
# ....A....G.......A.AC.. True
# A...T....G......C...C.. True
# .A..GT..........T...T.. True
# ..........TT......G.... True
# ....T...T.T.....C.G.... True
# ..AT........C..G...A... True
# ......A..G..A.....AA... True
# T......G.AG........G... True
# T....A....A.......TG... True
# .....T..G..T.......C... True
# ..A.T...T.....C.....C.. True
# T....A....A........GG.. True
# ..A.....T.G.....T...T.. True
# ......A..........TA.T.. True
# ..A....GC..G......G.... True
# G......AT.....C...G.... True
# ....T..A...G..A.....T.. True
# ..A..A.T......T.....C.. True
# .C..T.....G.........G.. True
# ------
# TCTGCTGCCCTTCTGTACCGTGG + ['7|2R|48714366|48714389|TCTGCTGCCCTTCTGTACCGTGG|+', '-', '2R', '48714365', 'TCTGCTGCCCTTCTGTACCGTGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# G.A..A..AT............. True
# CGA.......CA........... True
# GG.....G..GG........... True
# G.C...T...A..G......... True
# G...T.....GA...C....... True
# ...CG..G.....C.C....... True
# .......GT..A.C......... True
# ...C...AAT...A......... True
# .AA...C..T....C........ True
# .T......A..A..CC....... True
# .T.A.A.........G....... True
# ....T...TG........T.G.. True
# .G..G..G.A........G.... True
# ....T...GT........AT... True
# .T....TT.........TT.... True
# .G.......T......T.GT... True
# G........G......TTG.... True
# ........T....C..T...... True
# ......T.G...TC...G..... True
# ..G....A..C..G....A.... True
# ....T....A..G.A...A.... True
# ....T.T...C...C...A.... True
# G..C........G..C..G.... True
# A...........T.T...T.... True
# A.....T...A....C....A.. True
# A.....A......C....G.C.. True
# AT.T..C.............C.. True
# ...CT.T..T.........T... True
# A......T..........GA... True
# G....C...G........T.C.. True
# G........G.......G..G.. True
# A.A.....A........GT.... True
# ...T..T.A.......T.A.... True
# ...T..T.A.......T.A.... True
# G....G.T........TT..... True
# G.....TT........C...... True
# G.......TTG.....T...... True
# .A.....TG...T...G...... True
# ..A...A.G..G......T.... True
# ..A.....G..A.A....T.... True
# C........G.....G.AT.... True
# .T..G.....C..C....A.... True
# ..CC.A.......A....A.... True
# ....A....T.....A..AT... True
# A............A....GT... True
# ..CC.......G....G..C... True
# .T.....T.G.G........G.. True
# .......TT..A......G.A.. True
# ------
# TGCCCTTCTGTACCGTGGTGCGG + ['8|2R|48714371|48714394|TGCCCTTCTGTACCGTGGTGCGG|+', '-', '2R', '48714370', 'TGCCCTTCTGTACCGTGGTGCGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# CTA...G..C............. True
# C..TT...G..T........... True
# ...G....C.G.A.......... True
# ...G.....TCG.G......... True
# GAA........T.G......... True
# .T......CT.T.T......... True
# GTA...G.......T........ True
# .....AA.G....AA........ True
# G.......G..G.T.C....... True
# ....GGG..C.....A....... True
# ..T....TCCC............ True
# ..TTTG.....G........... True
# ....G..T..A.G.......... True
# G..A..C.A...T.......... True
# ....AGC......G......... True
# .....AA.G....AC........ True
# .A.A..C......TT........ True
# ....A....T.T...C....... True
# G.G.AG.............C... True
# .....GC.A..........AG.. True
# ...TGC...........TG.... True
# ..A.ACG.........A...... True
# .C...A..G.......T.C.... True
# A.......A.......C.CA... True
# .C..A...A.C......T..... True
# ....T...C..G..A..C..... True
# ....A.G.C..T.....A..... True
# ....A.G.C..T.....A..... True
# G......TG....G...A..... True
# .C.A......G..G...A..... True
# .T..AC......A.....G.... True
# .....AC.C....G....G.... True
# ..TG..G...G.......C.... True
# CA.........CA.....C.... True
# GT....G........C...C... True
# ...G...........C.T.C... True
# .C.....T.T.C.......T... True
# .....C..C..G.....C.T... True
# A.G..G.........A....T.. True
# .CT.G...G........A..... True
# ...AGCG.........C...... True
# G.T....T.......AT...... True
# .T..G.C.....G...C...... True
# ...G....C..G.G..C...... True
# ...G....C..G.G..C...... True
# .C......CC.T.....C..... True
# .TT.....C..G.....C..... True
# ....T....TC..T...C..... True
# ....T...C..G..A..C..... True
# ...G...G.....AA..C..... True
# ....A.G.C..T.....A..... True
# .CAG......C.......C.... True
# ....G...C..T........G.. True
# .T.A........GT......T.. True
# G..G.........G.....CT.. True
# G..G.........G.....CT.. True
# .A..T.....A.G.......A.. True
# ------
# AAACACTAGTTTGAACTTATCGG + ['9|2R|48714413|48714436|AAACACTAGTTTGAACTTATCGG|+', '-', '2R', '48714412', 'AAACACTAGTTTGAACTTATCGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# TC...A.CC.............. True
# ......A.T..A.TT........ True
# ..T.TG..A......A....... True
# .G.AC..T.......T....... True
# G..A..G.A......T....... True
# T...GA......C..T....... True
# C...T........G.G....... True
# .....A..T.C.T..T....... True
# ......G..C.......GT.... True
# ...G..A..........GGG... True
# .....GAG........AA..... True
# .....AC.........G.TC... True
# .....AC.........G.TC... True
# .C.....C...C.G..C...... True
# ....TA..T....T..C...... True
# ...A.....C....G.GA..... True
# ......AG.A.G......T.... True
# ...T.A.G....C.....T.... True
# .T..G..T.......G..T.... True
# ...A....A...A..T..G.... True
# ...A....A...A..T..G.... True
# .....A.G.A...C....C.... True
# G.......A.....TG..C.... True
# G.....C......CC....G... True
# G......G..A.....A..C... True
# ....T...T......TC...A.. True
# .....AC.........G..C... True
# .....AC.........G.TC... True
# .....AC.........G.TC... True
# .....AC.........G.TC... True
# .C.A.T......C....C..... True
# C.G......A.C.....G..... True
# C..A.........G.T..T.... True
# ...A..A......C.A..T.... True
# ......A....G....A.T.... True
# .T......CAC.......G.... True
# .....AC........TG..C... True
# .T......T.AC........T.. True
# ......A..G.G...T....T.. True
# .....T.T..A......C..T.. True
# ------
# ATCGGCATCAGTTGCGCACGCGG + ['10|2R|48714431|48714454|ATCGGCATCAGTTGCGCACGCGG|+', '-', '2R', '48714430', 'ATCGGCATCAGTTGCGCACGCGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# ..AC.A.C.C............. True
# TG....GA.G............. True
# ...A...G...CA..A....... True
# .C.....G..C..T.C....... True
# ....AG...G..C.......... True
# G.A....C......T........ True
# G.T.....AT..........T.. True
# ...AT..A....C...T...... True
# ..T...CC.....T...C..... True
# .G.A.......C...C..T.... True
# .GT....G.....A....A.... True
# T........G...C..A.A.... True
# G..T.....G....T....C... True
# ........T...G.T....A... True
# ..G......GC.....A..A... True
# ....A..G....C.A....T... True
# ....A..G....C.A....T... True
# ....A..G....C.A....T... True
# .....A...G...C....AT... True
# ...T.T....C.....G...G.. True
# .A......A...A....C..G.. True
# .......AA....C......A.. True
# G..A.........C..G...... True
# T.G......GC.....T...... True
# T....G.A.....T..T...... True
# .........C.G....TG..... True
# C......A...C..G...G.... True
# ...A..TG.......C..G.... True
# ...T...C..A......T.T... True
# ------
# CACACCCACATACAAAGATACGG + ['11|2R|48714508|48714531|CACACCCACATACAAAGATACGG|+', '-', '2R', '48714507', 'CACACCCACATACAAAGATACGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# G.A..A...GG............ True
# .G..AT..G...T.......... True
# .G....A...C...G........ True
# A.A.A......G..G........ True
# .....AA...C.G.G........ True
# .....A....C...C........ True
# ..AT.A....C...C........ True
# ....GA....C...C........ True
# .....A...TC...C........ True
# .....A....C...CC....... True
# .C..TG..A.C............ True
# TT....T....TA.......... True
# ...CA....CA.T.......... True
# A.A.A......G..G........ True
# A.A.A......G..G........ True
# A.A.A......G..G........ True
# A.A.A......G..G........ True
# A.A.A......G..G........ True
# ....AT....CC..T........ True
# ....AA....C...C........ True
# .....A....C..GC........ True
# .T...A..............A.. True
# .....A..G.........CGT.. True
# .....AT..C.......GC.... True
# ..AG.A...........C..T.. True
# T....ATG........C...... True
# ..T.GA..........C.C.... True
# ..A..A...T......A.A.... True
# .....AA.........A.A.A.. True
# .....A...G......TG..... True
# .C...A..A.C.....C...... True
# ....AA....CT....C...... True
# ...T.T..A..G....C...... True
# G....A....C.T...C...... True
# T....A....C..G..C...... True
# ...T.A....C..C..C...... True
# ..T..AT.......T.C...... True
# .....A....C...T.C...... True
# .....A....C...T.C...... True
# A....A....C...T.C...... True
# A....T....C...G.C...... True
# ....G...T..G..G.C...... True
# .....A........C.C...... True
# .....A...G....C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# A....A....C...C.C...... True
# A....A....C...C.C...... True
# A....A....C...C.C...... True
# .T...A....C...C.C...... True
# .T...A....C...C.C...... True
# ..A..A....C...C.C...... True
# ..A..A....C...C.C...... True
# ....AA....C...C.C...... True
# ....GA....C...C.C...... True
# .....AG...C...C.C...... True
# .....A.C..C...C.C...... True
# .....G.T..C...C.C...... True
# .....A..G.C...C.C...... True
# .....A...TC...C.C...... True
# .....A....A...C.C...... True
# .....A....A...C.C...... True
# A....A....A...C.C...... True
# A....A......T.C.C...... True
# A....A...GC.....T...... True
# G....A....C...T.T...... True
# A....A....C...T.T...... True
# ...G.A........C.T...... True
# .....A....C...C.T...... True
# .G...A....C...C.T...... True
# ..A..A....C...C.T...... True
# .....A.G..C...C.T...... True
# .....A..T.C...C.T...... True
# .....A..G.C...C.A...... True
# .G...A....C...C..G..... True
# .....A....C...C..T..... True
# .....A........C.CT..... True
# ......AGG....C...C..... True
# .....G....C...C..C..... True
# .....A....C...C..C..... True
# A....A....C.....CC..... True
# .....A....C...G...G.... True
# .....A..T.C...G...G.... True
# ...CG.....C...C...G.... True
# .....A....C...C...G.... True
# .....A....C...C...G.... True
# A....A....C...C...G.... True
# .....A.G..C...C...G.... True
# .....A...G.G...C..G.... True
# .....A....C.....T.G.... True
# .....A....C.....C.G.... True
# .....A........C.C.G.... True
# .....A........C.C.G.... True
# .....AA.......C.C.G.... True
# ...C..G.A.G.......C.... True
# .....A....CC......C.... True
# .....A..G.C...G...C.... True
# ..T..AT.......C...C.... True
# .....A....C...C...C.... True
# .....A....C...C...C.... True
# .....A....C...C...C.... True
# .....A....C...C...C.... True
# .....A....C...C...C.... True
# .....A....C...C...C.... True
# .....A....C...C...C.... True
# .....A.G.....GC...C.... True
# .....A..A....GT...C.... True
# .....G.G......CT..C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# T....A....C.....C.C.... True
# A....A....C.....C.C.... True
# .T...A....C.....C.C.... True
# ...G.A....C.....C.C.... True
# .....G....C.....C.C.... True
# .....AA...C.....C.C.... True
# .....G.T..C.....C.C.... True
# .....A.G..C.....C.C.... True
# .....A..A.C.....C.C.... True
# .....A..A.C.....C.C.... True
# .....A..T.C.....C.C.... True
# .....A........C.C.C.... True
# .....A........C.C.C.... True
# .....A........C.C.C.... True
# .....A........C.C.C.... True
# A....A........C.C.C.... True
# ..T..A........C.C.C.... True
# .....G........C.C.C.... True
# ....TT........C.C.C.... True
# .....A.T......C.C.C.... True
# ...C.A........T.C.C.... True
# .....A........G.C.C.... True
# T....A....C.....T.C.... True
# .T...A....C.....T.C.... True
# .C...A........C.T.C.... True
# .....A....C.....A.C.... True
# ....AA....C.......A.... True
# .....G....C...C...A.... True
# ..T..A....C....T..A.... True
# .....A....C.....A.A.... True
# .....A.G......C.A.A.... True
# ..G..A....C.....C.A.... True
# .....AT...C.....C.A.... True
# .....A..T.C.....C.A.... True
# .....A........C.T.A.... True
# .....A....C......GA.... True
# .....A....C.....C..C... True
# ....TG........C.C..C... True
# .....A......G...C..T... True
# .....A...T....C.C..T... True
# .....A....C.....T..T... True
# .....A...GC.....A..T... True
# .....A.........C.G.T... True
# .T...A........C..T.T... True
# ......A.A....C....AT... True
# .....A........C...GT... True
# .....A........C....G... True
# ..T..A........C....G... True
# .....A....C....C...G... True
# .....A....C.....C..G... True
# ........GC.....CC..G... True
# .....A....A.......GG... True
# ..G...AT....A.......T.. True
# .....A.....G..C.....T.. True
# A....A....C.....C...T.. True
# A....A........C.C...T.. True
# .....A...T....C.C...T.. True
# .....A........T.T...T.. True
# .....AT.......T.T...T.. True
# .....A...G....C.T...T.. True
# .....A..A..C......A.T.. True
# .....A....C...C.....A.. True
# ..T..A....C.....C...A.. True
# .....A........C.C...A.. True
# .....A........G..G..A.. True
# .....A........G...A.A.. True
# ....AA........C...G.A.. True
# ..T..A....C...G.....G.. True
# ..T..A........C...C.G.. True
# .....A........T...C.G.. True
# ....T...A.........AC... True
# .G...TT..C........C.... True
# ..A..A..AT.......T..... True
# ....AGA..........T.T... True
# .....A.T.........TAT... True
# ...GGA..........A.A.... True
# .....A...G......A.C.G.. True
# ..T.AG..A.......T...... True
# .....A...C......T..GG.. True
# ....TT..........T..GT.. True
# ..T..A..........C.C.... True
# A......C........C.CC... True
# .G.T.A....C.....C...... True
# ....AA.....T....C...... True
# ....AA....CT....C...... True
# ..T..AT.......T.C...... True
# .CTC..........C.C...... True
# .....A........C.C...... True
# .....A........C.C...... True
# .T...A..A.....C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# .....A....C...C.C...... True
# G....A....C...C.C...... True
# .G...A....C...C.C...... True
# .G...A....C...C.C...... True
# .C...A....C...C.C...... True
# .C...A....C...C.C...... True
# ..T..A....C...C.C...... True
# ..G..A....C...C.C...... True
# .....AT...C...C.C...... True
# .....A..A.C...C.C...... True
# .....A...GC...C.C...... True
# .....A.C..A...G.C...... True
# G....A....C...G.C...... True
# .....T........C.A...... True
# ...T.G....C...C.A...... True
# .....A....C...C.A...... True
# ..A..A....C...C.A...... True
# .....A..T.C...G.A...... True
# .....AT...C.....T...... True
# ......GGG...A...T...... True
# T....A....C...C.T...... True
# .....A....C...T.T...... True
# .....A..A..G...GT...... True
# ...C.A........C..G..... True
# .....A...TC...C..G..... True
# A....A........C.CG..... True
# .....AT.......C.CG..... True
# .....GA...C.....AC..... True
# .....A........T.CC..... True
# ..T..A....A.....AT..... True
# .....A....C.....CT..... True
# .....A........C.CT..... True
# ........A.CC......A.... True
# A....G....GC......A.... True
# .....A....C..T....A.... True
# ....GA........G...A.... True
# .....A....C...G...A.... True
# .....A....C...G...A.... True
# .....A........T.C.A.... True
# .C.T......A.....A.A.... True
# .T...G.......G..T.A.... True
# ...C.T....A......GA.... True
# ...C.T....A......GA.... True
# .....A........C..CA.... True
# A....A....C...G...G.... True
# G....A........C...G.... True
# ...GGA........C...G.... True
# .....A....C...C...G.... True
# .....A....C...C...G.... True
# .....A....C...C...G.... True
# T....A....C...C...G.... True
# G...TA........T...G.... True
# A....A........G.C.G.... True
# T....A........C.T.G.... True
# .....AT.......G..TG.... True
# G.......GGG.......C.... True
# ....G.A.A...G.....C.... True
# ...G.A....C...T...C.... True
# ....GA....C...T...C.... True
# .....A........C...C.... True
# .....A.T......C...C.... True
# A....A....G...C...C.... True
# .....A....C...C...C.... True
# .....A....C...C...C.... True
# .G...A....C...C...C.... True
# ....TA....C...C...C.... True
# ....TA....C...C...C.... True
# ....GA....C...C...C.... True
# .....A..T.C...C...C.... True
# .....A....C....G..C.... True
# .....A...C.T...G..C.... True
# .....A...T....CG..C.... True
# .....A....C....C..C.... True
# A...A.....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# .....A....C.....C.C.... True
# T....A....C.....C.C.... True
# G....A....C.....C.C.... True
# G....A....C.....C.C.... True
# ...G.A....C.....C.C.... True
# ....AA....C.....C.C.... True
# .....AT...C.....C.C.... True
# ......G...C.....C.C.... True
# .....A...GC.....C.C.... True
# T....A....A.....C.C.... True
# .....A......G...C.C.... True
# .....A......G...C.C.... True
# .....A........C.C.C.... True
# .....A........C.C.C.... True
# .....A........C.C.C.... True
# ..A..A........C.C.C.... True
# ...G.A........C.C.C.... True
# .....G........C.C.C.... True
# .....T...G....C.C.C.... True
# .....A........G.C.C.... True
# .....A........T.C.C.... True
# .T...A........T.C.C.... True
# ....AA........T.C.C.... True
# .....A....C.....T.C.... True
# .....A........C.T.C.... True
# .....T........C..TC.... True
# T....A....C...C....C... True
# .....A....C....C...C... True
# .....A....C.....C..C... True
# ..T..A........C.C..C... True
# .....A........T.A..C... True
# .....A....C.......CC... True
# G....G........C...CC... True
# .....A...G.G..G....G... True
# .....A........C.C..G... True
# ...C.A........C.C..G... True
# ....TA........C.C..G... True
# .....A.G......C...GG... True
# ....AA........C.C..T... True
# ..A..A....C.......CT... True
# G.A..T......A.......A.. True
# .....A....C...G.....A.. True
# G....G.G.......C....A.. True
# .....A....C.......C.A.. True
# .....A....C.......C.A.. True
# ...T.A........C...C.A.. True
# .....A....C.......A.A.. True
# .....A....C.......A.A.. True
# .....AT...C.......A.A.. True
# .....AT...C.......A.A.. True
# .....A.G..C.......A.A.. True
# .....A..G.C.......A.A.. True
# .....A.....G......A.A.. True
# .....A........C...A.A.. True
# .....A....C...C.....T.. True
# .....A....C...C.....T.. True
# .....A....C.....C...T.. True
# ..A..A......T...T...T.. True
# .....AG...A......G..T.. True
# ....TA........C..C..T.. True
# ....AA....C.......G.T.. True
# G.A..A......G.......G.. True
# T....A........C.A...G.. True
# .....A.........TA...G.. True
# .....A....C......G..G.. True
# ...G.T....A.......G.G.. True
# .....A........C...G.G.. True
# .....A.C......C...G.G.. True
# ....AA........G...C.G.. True
# .....A........C...C.G.. True
# ------
# AAAGATACGGACAGTTACAGTGG + ['12|2R|48714521|48714544|AAAGATACGGACAGTTACAGTGG|+', '-', '2R', '48714520', 'AAAGATACGGACAGTTACAGTGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# .G.A.....AT..T......... True
# .C......A..ACA......... True
# G.T.....AC.....G....... True
# G.C..C...A.....G....... True
# .....G..A.....CG....... True
# G....C.....T..GG....... True
# ..G..C.......TGG....... True
# .........A.G..CA....... True
# ..G....T........T...C.. True
# ...T..G.A.......T..C... True
# GG....T........AG...... True
# ......TT......AA.T..... True
# ....GG...C....A..A..... True
# ...C.C......GT....G.... True
# .G....T..A...A.....C... True
# ...C.C.A.....T.....C... True
# ...A..C......T...G.A... True
# .....A.A.......G.G..A.. True
# T....C.G.......A....C.. True
# ..T.G.GG............A.. True
# .C.C.A..........T..T... True
# .C.C.A..........T..T... True
# ...A.C..A.C.....C...... True
# ....G.T.C......GG...... True
# ...A...G.AT......A..... True
# .....C.G.....T...GT.... True
# ..G....A...A.C.....T... True
# .C.C....A.....A.....C.. True
# ------
# TACGGACAGTTACAGTGGTGCGG + ['13|2R|48714526|48714549|TACGGACAGTTACAGTGGTGCGG|+', '-', '2R', '48714525', 'TACGGACAGTTACAGTGGTGCGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# G..A.T..A.G............ True
# ....AGG..CA............ True
# .CG....G.G.....A....... True
# CC..T....G.....C....... True
# ......A..G..A.CC....... True
# ACA......GG............ True
# .....CAGA..G........... True
# .GT.C..G....T.......... True
# C......GCC..........G.. True
# ...A....T........C.AG.. True
# A......C...C..C.C...... True
# ..GCC.......T...T...... True
# .C....A..GA.......G.... True
# G.T...G....G.......T... True
# G..A.....A.....C...A... True
# ...T....C..G......CA... True
# .T.......A.G.T......A.. True
# AT.C......G.........T.. True
# C..AC.......T.......T.. True
# A.A.A............A..A.. True
# .C.T.....C.......A.A... True
# .C..T...........T..C... True
# .......G...G.G..T...... True
# .C.....GA....G..A...... True
# G....C...C....A.C...... True
# .TGC......G......A..... True
# AG........C.....T.A.... True
# .G..T.....CG.......C... True
# ------
# AAGTTTATCATCCACTCTGACGG + ['14|2R|48714550|48714573|AAGTTTATCATCCACTCTGACGG|+', '-', '2R', '48714549', 'AAGTTTATCATCCACTCTGACGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# .....CC..C..AT......... True
# .....CC..C..AT......... True
# ..T.........TC.C....... True
# ..AAG..AA.............. True
# ......TC....A.AG....... True
# .....C...C.......G.GA.. True
# ..A...T.........A.C.... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....AG.A.......AA...... True
# ....AG.A.......AA...... True
# ....CG.A.......AT...... True
# ....CG.A.......AT...... True
# ....CG.A.......AT...... True
# ....CG.A.......AT...... True
# ..A...T........GAC..... True
# G..A.......T...C.A..... True
# ......TG..A...T...A.... True
# ..C...C........C..CG... True
# ..C...T.....AG.....C... True
# .....C...T...C...C.C... True
# ...A.C.C......G.....T.. True
# ....G.G.....A...G...T.. True
# .TT..........CT.....A.. True
# ..A...T....T......T.A.. True
# ..A..C.C..........CC... True
# C..........G....T...... True
# ....CG.A.......AT...... True
# ....CA.A.......AT...... True
# .....G.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....CG.A.......AA...... True
# ....AG.A.......AA...... True
# .....A.C....A..AG...... True
# ..A..G......AT...C..... True
# .TT.......C....C...G... True
# C.T....A.......G....A.. True
# ------
# AGTTTATCATCCACTCTGACGGG + ['15|2R|48714551|48714574|AGTTTATCATCCACTCTGACGGG|+', '-', '2R', '48714550', 'AGTTTATCATCCACTCTGACGGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# G......GT.T....A....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...AG.A.......AA....... True
# ...AG.A.......AA....... True
# ...CG.A.......AT....... True
# ...CG.A.......AT....... True
# ...CG.A.......AT....... True
# ..CA...TT....T......... True
# ....G.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...CG.A.......AA....... True
# ...AG.A.......AA....... True
# ...CA.A.......AT....... True
# ...CG.A.......AT....... True
# T....T.A........G.G.... True
# ....C...C.......G.GA... True
# ..A.......T...C.A...... True
# T....C.....A....CA..... True
# .C...C........C..CG.... True
# ...G.G.....A...G...T... True
# ...A....T..G.....C.A... True
# ..C..G........CT....C.. True
# .A..C.C..........CC.... True
# ..C.C.......CG..G...... True
# .T.AA..........T.T..... True
# .....C..C....T.G..T.... True
# .A.....G.....T...T.T... True
# .T...C..T...T......G... True
# .T...C..T...T......G... True
# ......AT..G...G.....A.. True
# C.......T.A........GC.. True
# ------
# TTATCATCCACTCTGACGGGTGG + ['16|2R|48714554|48714577|TTATCATCCACTCTGACGGGTGG|+', '-', '2R', '48714553', 'TTATCATCCACTCTGACGGGTGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# A......TA.T.A.......... True
# A..C..A.....GA......... True
# ...C......TC...G....... True
# ...A.G.......CAT....... True
# CC...G.......A.C....... True
# ..C..T...T......G...G.. True
# ..CG......G....GG...... True
# ....T...G.T....TG...... True
# ..CCA.........A..C..... True
# ........GGG....C.T..... True
# .CG..........A.G..A.... True
# ...C..C..C.....C..A.... True
# ...C..GA.......C..T.... True
# .......A.T.G.....C.C... True
# ....G..G..A.T......T... True
# ....G.C..G.G.......A... True
# .....G.GA......T...A... True
# ....T...T.TA........A.. True
# ........AC.G..C.....A.. True
# ....G..GA.......T.A.... True
# ........G.......A.T.G.. True
# A..AT.A.........G...... True
# ..C..T...T......G...G.. True
# ..C..T...T......G...G.. True
# .C..A.......T.C..T..... True
# ..T...C..C.....C.C..... True
# ...AA.......T...A...G.. True
# ------
# ATAGTAGATCCTAGAGCAGGTGG - ['17|2R|48714180|48714203|ATAGTAGATCCTAGAGCAGGTGG|-', '+', '2R', '48714179', 'CCACCTGCTCTAGGATCTACTAT', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# TCT.A.......C.......... True
# GG.......T.C.C......... True
# .A.C..A....C.T......... True
# ..G....CG....AG........ True
# ..C..T.C.G.......T..... True
# ..T...T.A..A....A...... True
# .C...T......TC...C..... True
# ....G...AG..G.....A.... True
# ....G...AG..G.....A.... True
# ....C...A.G.G.....C.... True
# .C..C.......G.T....C... True
# ....AT...AA.........C.. True
# T..A..A..T.........T... True
# GCG.C...........A...... True
# ..G......G......G.AA... True
# ....A..GA.A.....A...... True
# ....A..GA.A.....A...... True
# ....A..GA.A.....A...... True
# .......TA.GC....A...... True
# .C....C..G...T..A...... True
# T.G..........C.AA...... True
# .......T.G.A....AG..... True
# ..C......GT.....G.A.... True
# ......C.G.A.......TA... True
# ..G....T....T....C.C... True
# ------
# TACATAGTAGATCCTAGAGCAGG - ['18|2R|48714183|48714206|TACATAGTAGATCCTAGAGCAGG|-', '+', '2R', '48714182', 'CCTGCTCTAGGATCTACTATGTA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# .T...GA...G...C........ True
# ....A..CCA.......G..... True
# AG.......T......C.C.... True
# ......A.T...G...A...... True
# ....C....A...T...G.A... True
# ....C.A....A.A......T.. True
# ......AG.....G.....AT.. True
# ......C.GT...A..C...... True
# .....G.C....T.C..G..... True
# ....C.T..C.G......T.... True
# .....G.G....G..G...A... True
# .T......T.G.T.......C.. True
# ..T......A.C.G......C.. True
# ....C.A....A.A......T.. True
# ....C.A....A.A......T.. True
# ------
# TGGTCGTCCCGTTCAAGAAACGG - ['19|2R|48714243|48714266|TGGTCGTCCCGTTCAAGAAACGG|-', '+', '2R', '48714242', 'CCGTTTCTTGAACGGGACGACCA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# .CAG.T....T............ True
# C.....C....GC..C....... True
# ..T.....TT.G.A......... True
# C.......TTT...T........ True
# ....G.AA.G....C........ True
# A.C....G...A..G........ True
# A.C....G...A..G........ True
# ......AA...A..TC....... True
# .....AC.....CA.G....... True
# ...G..A.G..........CG.. True
# ..T....TT.......A...T.. True
# ..A...A.G.......A.T.... True
# ..C.T..A......G.T...... True
# ....T....TT...G.A...... True
# .C.......G....G.CC..... True
# A.T............G..TG... True
# .....C..G...A...A...G.. True
# .C.......A.C...TC...... True
# C..G..........G.C..C... True
# ..T....A....C....G..T.. True
# ...C.C.G.......G....G.. True
# ..CA..........GG....A.. True
# ------
# GAGCAGCAAAAACAAAACAGTGG - ['20|2R|48714263|48714286|GAGCAGCAAAAACAAAACAGTGG|-', '+', '2R', '48714262', 'CCACTGTTTTGTTTTTGCTGCTC', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# AC.A.AA................ True
# TC..C.TC............... True
# ..AG.TAT............... True
# T.AA..T.G.............. True
# .C.A..TGG.............. True
# CG...A....G............ True
# .TAAT.......A.......... True
# A....A......A.......... True
# ..CGTA......A.......... True
# T.AA.C......A.......... True
# TT.A..A.....A.......... True
# A.A..AA.....A.......... True
# ..AA..T..C...G......... True
# C.......GC....G........ True
# A..G.A..T.....T........ True
# .G....TG..C....C....... True
# C.......GC.G...T....... True
# C.......TC....GG....... True
# .CA..CA................ True
# ...G.TA.C.............. True
# ....G...G.............. True
# T..G.T...C............. True
# ..AAT.T...T............ True
# CC........G............ True
# AGC.....G..C........... True
# ..AA.CG.....T.......... True
# .T.A.AA.....G.......... True
# ...A...GG.G.G.......... True
# ..AA.A......A.......... True
# ..AA.A......A.......... True
# A.C.C..G....A.......... True
# ......TCGG..A.......... True
# C.A......CG.A.......... True
# .....C...CG..C......... True
# .....C...CG..C......... True
# ...A....T...TC......... True
# ..CG...GG.....G........ True
# TT....A.....A.G........ True
# AT...TT.......C........ True
# C........C....C........ True
# ......A.C.T.A.C........ True
# A..A.......CA.C........ True
# ..A..AG.....G.C........ True
# .CT.T.A........C....... True
# C.......GC.G...C....... True
# T..A..G..G.....T....... True
# ....T.G...C....T....... True
# ..A......T..AT.T....... True
# ...T..A.....A.GT....... True
# C.A..A...C..........A.. True
# ..CA.A...C..........A.. True
# AG...A...G..........C.. True
# ...TCA.............AA.. True
# A.A.....TT.........C... True
# ...AGAG...........C.... True
# ..A..AA...........C.A.. True
# ....T.GT..........G.C.. True
# C..T.A..G........A..... True
# A.A..A...C.......A..... True
# ..AT....GC.......A..... True
# .....AAC.........A..C.. True
# ..T.T....C.......A..A.. True
# CCA..............A.A... True
# A........C.......A.A... True
# C.A......C.......A.A... True
# AC...............A.AA.. True
# .....A...C.......A.AA.. True
# .....A...C.......A.AG.. True
# .....A...C.......A.AG.. True
# .G......C........A.CG.. True
# .....A...C.......A.CA.. True
# .....CG.G........G.A... True
# ..A..A...C......C.C.... True
# .T.T............G..AA.. True
# .C.A...G........G..T... True
# ..A.....GC......G..T... True
# ...TT...........GG..... True
# A....C..G.......T...... True
# .T....G...CG....C...... True
# ..TTT......G....T...... True
# ......AC..C...G.G...... True
# ..A.T.A...T......A..... True
# C.......GC.G.....A..... True
# A.......GC.G.....A..... True
# C.A......G..A....A..... True
# ...G..A...G......G..... True
# C...........G....G..... True
# ..T...A....G......G.... True
# ...G.A..C...A.....G.... True
# C......G..C.A.....G.... True
# ........TT.G.G....G.... True
# ...A....C.G......AG.... True
# A....A....C.T......T... True
# C..G...........T.T.T... True
# ..C.TA......A......C... True
# A..A..A.....A......C... True
# A....A...C..A......C... True
# ..A...AT......C....C... True
# .....AA.....A.C....C... True
# .........C.....C...C... True
# ...A...G....A....A.C... True
# .GTA........A......A... True
# C....AA.....A......A... True
# C.C.........A...C..A... True
# ....T.T...G......A.A... True
# T..A........A....A.A... True
# .T.A........A....A.A... True
# .....A...C.....C.A.A... True
# .G.......G....C..G.A... True
# A.A........T......GA... True
# ...A..A.......C...GA... True
# .......G...GA.......A.. True
# ...AG........G..C...A.. True
# .G...C.....C.......AA.. True
# .....A......A......AA.. True
# ...A.....G.....G...AA.. True
# C....TA.....A.......G.. True
# ...A..A.......TC....G.. True
# ...A.A.........TT...G.. True
# .....A....G......A..G.. True
# CG.............C.G..G.. True
# C........C.G......G.G.. True
# AC...A........G.....C.. True
# .C...A...C.....C....C.. True
# T..........G.......AC.. True
# .G....T.....A......CC.. True
# TGT..A..............G.. True
# ..AA.AT.............G.. True
# ..TAG....T..........G.. True
# .C.T..AG...........A... True
# ..TA.C.............AC.. True
# ..T..TT.C..........T... True
# A.....G..G.........TG.. True
# TGT....C..........G.... True
# ....G..CT.........G.... True
# C.A..A...C........G.... True
# C.......CG........C.C.. True
# .CA.....C........A..... True
# C.T...A.G........A..... True
# A.A..A...C.......A..... True
# C.A..A...C.......A..... True
# A.......GC.......A..... True
# ........C........A..C.. True
# C....A...C.......A..C.. True
# T....A...C.......A..A.. True
# ........GC.......A..G.. True
# AT.A.............A.A... True
# .TAA.............A.A... True
# .G...CA..........A.A... True
# ......GC.C.......A.A... True
# .G.A.............A.AG.. True
# A.......T........A.AC.. True
# A....A...........A.AA.. True
# C........C.......A.AA.. True
# ...A.....C.......A.T... True
# ...TG............A.TA.. True
# .....A...C.......A.CA.. True
# ..A..A...........G.AC.. True
# ...
# ..T........G.......GG.. True
# ..T........G.......GG.. True
# ..T........G.......GG.. True
# ..T........G.......GG.. True
# ..T........G.......GG.. True
# ..T........G.......GG.. True
# C.T........G.......GG.. True
# C.T........G.......GG.. True
# C.T........G.......GG.. True
# C.T........G.......GG.. True
# G.T........G.......GG.. True
# G.T........G.......GG.. True
# G.T........G.......GG.. True
# A.T........G.......GG.. True
# A.T........G.......GG.. True
# A.T........G.......GG.. True
# A.T........G.......GG.. True
# A.T........G.......GG.. True
# A.T........G.......GG.. True
# A.T........G.......GG.. True
# .TT........G.......GG.. True
# .TT........G.......GG.. True
# .TT........G.......GG.. True
# .TT........G.......GG.. True
# .TT........G.......GG.. True
# .TT........G.......GG.. True
# .TT........G.......GG.. True
# .AT........G.......GG.. True
# .AT........G.......GG.. True
# .CT........G.......GG.. True
# ..A........G.......GG.. True
# ..A........G.......GG.. True
# ..A........G.......GG.. True
# C.A........G.......GG.. True
# A.A........G.......GG.. True
# C.C........G.......GG.. True
# C.C........G.......GG.. True
# G.C........G.......GG.. True
# .TC........G.......GG.. True
# .A.T.......G.......GG.. True
# ..TT.......G.......GG.. True
# ..TT.......G.......GG.. True
# ..TT.......G.......GG.. True
# ...A.......G.......GG.. True
# C..A.......G.......GG.. True
# ..TA.......G.......GG.. True
# ..TA.......G.......GG.. True
# ..CA.......G.......GG.. True
# ..TC.......G.......GG.. True
# ....A......G.......GG.. True
# ..T.A......G.......GG.. True
# C...C......G.......GG.. True
# ..T.C......G.......GG.. True
# G....A.....G.......GG.. True
# ..T..A.....G.......GG.. True
# ..T...C....G.......GG.. True
# ..T...G....G.......GG.. True
# ..T...A....G.......GG.. True
# ..T....A...G.......GG.. True
# ..T....A...G.......GG.. True
# ..T.....A..G.......GG.. True
# ..T.....C..G.......GG.. True
# .C.......C.G.......GG.. True
# ..T......C.G.......GG.. True
# ..C......A.G.......GG.. True
# ..T......A.G.......GG.. True
# ..T........T.......GG.. True
# ..T........T.......GG.. True
# ..TA.......T.......GG.. True
# .CT........C.......GG.. True
# ..T......A.....A...GG.. True
# ..T.A.....C........AG.. True
# ...........G.......AG.. True
# G..........G.......AG.. True
# .C.........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# ..T........G.......AG.. True
# G.T........G.......AG.. True
# C.T........G.......AG.. True
# C.C........G.......AG.. True
# .CC........G.......AG.. True
# ..TT.......G.......AG.. True
# ..T.C......G.......AG.. True
# ..T......C.G.......AG.. True
# ..T........T.......AG.. True
# ..T.C......T.......AG.. True
# ------
# CTGTCCGTATCTTTGTATGTGGG - ['42|2R|48714512|48714535|CTGTCCGTATCTTTGTATGTGGG|-', '+', '2R', '48714511', 'CCCACATACAAAGATACGGACAG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# G...GT..G.G............ True
# G...GT..G.G............ True
# G...GT..G.G............ True
# A...TG..G.G............ True
# ....GT.CG.G............ True
# A...GT....G.G.......... True
# G...GT....G.G.......... True
# G....G..G.G.G.......... True
# A...T....CG.G.......... True
# ..TC..A...T.G.......... True
# ....G.C.G...C.......... True
# G...G...G.G...A........ True
# G...G...G.G...A........ True
# G....T....G.G.A........ True
# G...G.....G.G..C....... True
# ...A....T..C.G.C....... True
# ..C..TC.G...G.......... True
# T...TT....G.G.......... True
# G....T..G.G.G.......... True
# A...AT....G.A.......... True
# ...C.G..T.G.A.......... True
# ....GT....G.G.A........ True
# ..C...CCC.....C........ True
# T...A.A.G.........T.... True
# .AC..TT.........G...... True
# A...GT....G.....G...... True
# G...G...G.G.....G...... True
# G...TT......G...G...... True
# ...G.T..G...G...G...... True
# ......C.C...G...G...... True
# ........C.G.G...G...... True
# ....G...G.G.G...G...... True
# ....A...G.G.G...G...... True
# .....T..G.G.G...G...... True
# .....A..G.G.G...G...... True
# .....A..G.G.G...G...... True
# A...G.....A.G...G...... True
# T..C......G.A...G...... True
# T.....C.T.G.....C...... True
# G....T......G...CG..... True
# .....TC.C.T.......A.... True
# .....G..G....C...AA.... True
# .....G..G....C...AA.... True
# .....T...CG.....G.C.... True
# ....A..A..G.G......A... True
# ....G...T.....C.T..A... True
# ....TT.........C..TA... True
# ....G.T.T....G.....G... True
# .......GC....A.C...G... True
# .....A..T..CA.......A.. True
# ...C.....G..G..A....T.. True
# ..T..T..........TG..... True
# G....T..G.......G...T.. True
# ...C....GC......G...C.. True
# G...GT....G.....G...... True
# T...A.....G.G...G...... True
# ........G.G.G...G...... True
# .....T..G.G.G...G...... True
# G....T....A.G...G...... True
# G..A....T...C...G...... True
# G....T..G...A...G...... True
# G....T....A.A...G...... True
# .....T..G.G.A...G...... True
# .C.A.......A.G..G...... True
# ....GT....G.G...C...... True
# ..C..T..G.G.....T...... True
# ...CA.....G.G...T...... True
# ...CA....G....A.T...... True
# ..C.G.T.......C.T...... True
# ..T......C.C...CT...... True
# .....T..C.G.....TG..... True
# .....TC...G.....C.T.... True
# ..T...TA..A.........T.. True
# .....TT...T.....T...T.. True
# .A.C........C...G...T.. True
# .....T..C...C...G...T.. True
# ..C.T.....T........GT.. True
# ..T.G...G...G.......C.. True
# .....TC.....G....C..C.. True
# ------
# ACTGTCCGTATCTTTGTATGTGG - ['43|2R|48714513|48714536|ACTGTCCGTATCTTTGTATGTGG|-', '+', '2R', '48714512', 'CCACATACAAAGATACGGACAGT', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# .G....GC.G.G........... True
# .....GT.CG.G........... True
# .A...GT..G.T........... True
# GA...GT......G......... True
# .G...GT....G.G......... True
# .A....T..G.G.G......... True
# .T....G..G.G.G......... True
# .G...G...T.G.G......... True
# T....G.C.G...C......... True
# G....T...G.G.C......... True
# .G...G...G.G...A....... True
# .G...G...G.G...A....... True
# TG...GT..G............. True
# ....GGT..T.G........... True
# ..C..AT..G.T........... True
# ..A..GT...A.A.......... True
# TG...GT......G......... True
# .....GT..G.G.G......... True
# ..AA...A.T.......G..... True
# TT...A..........C..C... True
# .G....A..T..A...A...... True
# CG.C.........C..C...... True
# CG.C.........C..C...... True
# CG.C.........C..C...... True
# CG.C.........C..C...... True
# CG.C.........C..C...... True
# .T.A.T.....G.....T..... True
# ...TC.T....G.....G..... True
# C.G...A....G.....G..... True
# .....GT..G.G.....G..... True
# G.....A..G.G.....G..... True
# ...C...A.T..A....G..... True
# T......C.C...G...G..... True
# .G...G.....G.G...G..... True
# T........C.G.G...G..... True
# TT.......G.....A.G..... True
# ..GC.....T....C...C.... True
# .....GA....T....G..T... True
# .....G.T.T....G.....G.. True
# C....A......G....G..A.. True
# .....TT.C..A........C.. True
# G..T..T..........TG.... True
# ....AT..GT.......G..... True
# ...A.T...T.......G.T... True
# TG.......T.G....C...... True
# CG.C.........C..C...... True
# .....GG..G.G.....G..... True
# .....TT..G.G.....G..... True
# T.....T..G...G...G..... True
# T.....T....G.G...G..... True
# .....GT....G.G...G..... True
# G........G.G.G...G..... True
# .G.......G.G.G...G..... True
# ....G....G.G.A...G..... True
# ...T.G...G.G.....T..... True
# C........CC...C...C.... True
# ......TC...G.....C.T... True
# ------
# CGCAATACCACCCGTCAGAGTGG - ['44|2R|48714561|48714584|CGCAATACCACCCGTCAGAGTGG|-', '+', '2R', '48714560', 'CCACTCTGACGGGTGGTATTGCG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# ..A....GGTA............ True
# AA...C.....T.A......... True
# G......AA...T.G........ True
# GA.C............G.G.... True
# A......A.....AA.C...... True
# T.....C.A...T....A..... True
# ....CCG.....G....A..... True
# .....A..T.....G....A... True
# .CA..........C..C...G.. True
# A.....T.....A...G...A.. True
# .A..C..........G.C..C.. True
# .......AA......A..C.C.. True
# TT......A........A..A.. True
# .AA.C.......G...C...... True
# ....GC........AAC...... True
# A...G.......G....TG.... True
# ...G.C...G..G.....C.... True
# ....C.CG.....A....C.... True
# ..A....G....T.G....A... True
# ..A....G....T.G....A... True
# .CG..........A....T.C.. True
# ------
# TCTGAACATGTTTGATGGCGTGG - ['45|2R|48714589|48714612|TCTGAACATGTTTGATGGCGTGG|-', '+', '2R', '48714588', 'CCACGCCATCAAACATGTTCAGA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# ....G..TG...GA......... True
# C.C....G..G...T........ True
# ..CC...G.....TG........ True
# G..C...G.C....C........ True
# CG....A.C......C....... True
# .G.A....G..CG.......... True
# .A..C...C..G..C........ True
# G.A.....CA........T.... True
# C...C.A...........T.G.. True
# .T...T....AC.....C..... True
# .AC.C........C...C..... True
# .T..G.........T.TA..... True
# .....TT....G....T.T.... True
# .A...C.....A......TT... True
# ..G.G........T...T.A... True
# ..C..T....G..A......G.. True
# ..GT..A..A..........G.. True
# GA...T............G.C.. True
# ....T..T..G...C..A..... True
# ...T..T...C..A...C..... True
# G...........C.T...A.... True
# .T.....T...A.......C... True
# .T.....G.....T.A...C... True
# G........T....T..T.A... True
# CT........A...T....T... True
# ...T...T.T.....G...T... True
# ...T...T.T.....G...T... True
# AT............CG....C.. True
# ------
# ATAATCTGAACATGTTTGATGG - ['46|2R|48714594|48714617|CATAATCTGAACATGTTTGATGG|-', '+', '2R', '48714593', 'CCATCAAACATGTTCAGATTAT', 'IIIIIIIIIIIIIIIIIIIIII', '0', '']
# C.T..A.T............... True
# .AT..ACT............... True
# CG.C..GC............... True
# CC.T.T...T............. True
# T....A.TTT............. True
# G.G...CT.G............. True
# T.GC...C..A............ True
# T...AT..C.A............ True
# ..C.A...GCG............ True
# G..C....G..G........... True
# ..C....A.G.G........... True
# ..C.G..A.G.G........... True
# .C..G.A..G.C........... True
# ......C.C.AC........... True
# .GC.A.A.....C.......... True
# ..C..AA.G...G.......... True
# ..C..AA.G...G.......... True
# G..GG.....T.G.......... True
# .AG......T..A.......... True
# .A....A...TCA.......... True
# ..C..TAC.....A......... True
# ..G....C.C.T.A......... True
# T.......T...GA......... True
# C..T.T..G....T......... True
# .A...A....A.CT......... True
# .....G.C..G..C......... True
# .C...GA....C.C......... True
# ......C.GC..A.C........ True
# .A..G...C.G...A........ True
# .....G.C..T..TA........ True
# .....G.C..T..TA........ True
# .....G.C..T..TA........ True
# .....G.C..T..TA........ True
# .A..AT.A............... True
# .C.C.G.C.G............. True
# ...CA.AC...C........... True
# ..G.A....TGC........... True
# G...GTA....G........... True
# ..CT...A.G.G........... True
# ....AAAT...T........... True
# .CG...G.....A.......... True
# G.C...G....TC.......... True
# C.GT.......TG.......... True
# .A...T.A.T...A......... True
# ...TA..C.....T......... True
# .......TTC.C.T......... True
# .G......C.GC.T......... True
# .....GCC.....C......... True
# ....G....G..GC......... True
# ...TG..A..T...G........ True
# .....GG..C...AG........ True
# .G..A.G....G..A........ True
# .....G.C..T..TA........ True
# .....G.C..T..TA........ True
# ...C.TCA............T.. True
# .C...A..C..........CA.. True
# ......CC...........GC.. True
# .G......G..........GC.. True
# G.T..T..G.........G.... True
# .A..AA............T.T.. True
# .A.C..C.G.........C.... True
# .A..AA..G........C..... True
# C.T..T...........C..A.. True
# T.T..A.T.........T..... True
# T...C............TC.T.. True
# GA.C...A.........A..... True
# ..CC..CC.........A..... True
# .A...TCC........C...... True
# .A...TCC........C...... True
# .....TCA........C...C.. True
# .A.CAA.........C....... True
# ...C..C........C...GT.. True
# .......AC......CAC..... True
# .C.TG.A........A....... True
# .AC.....G......A....C.. True
# .....A..T.G..A.G....... True
# T....A.T..T....A....... True
# .AT..T......G..C....... True
# ..TG....T...G...G...... True
# TG............CAG...... True
# .AG....C..A.....C...... True
# G.G.......GT....C...... True
# ..GT......GT....C...... True
# ..G.AT...G......A...... True
# T.T..A....A.....A...... True
# .....T.T..GG....A...... True
# ......GT..AT.....T..... True
# ..T..T.T....C....T..... True
# .A...A.A......G..T..... True
# .....T.A..A......C..... True
# .C...TA...T......C..... True
# .C...A..G.....G..C..... True
# ...T.T.T....C....A..... True
# TA...........C...A..... True
# ....G..A.....C...A..... True
# ..GGC....C........T.... True
# TA..A......G......T.... True
# .A...T.....GC.....T.... True
# .......TG.A..T....T.... True
# ....C.G..G....A...T.... True
# .C.....C.T....G...T.... True
# ...CC......T..G...T.... True
# T......A......GC..T.... True
# ..C.....T....C..G.T.... True
# G....T....A.....C.T.... True
# T......T..A......TT.... True
# ...CCT.......T....C.... True
# .....TC......C...CC.... True
# .CC..........T...CC.... True
# ....C..T..G......AC.... True
# .GG.A.....G.......G.... True
# .G.C..........AA..G.... True
# ..C....A.G.G.......C... True
# ..GT......AG.......C... True
# .A...T.....G......TG... True
# C.......T...G......A... True
# ..T..G.......T...C.A... True
# ...T.G..T....T......T.. True
# .A...A....T..T......T.. True
# CA..A.........A.....T.. True
# C....T....G.....G...T.. True
# G.......C....C....G.T.. True
# .....T..C...A.....T.T.. True
# .A...T...T........C.T.. True
# ..C...A..T....C.....A.. True
# ..C...A..T....C.....A.. True
# ...G.A........CG....A.. True
# ...G...T.T.......C..A.. True
# ..G.....C....T....T.A.. True
# .C.....T...T......G.A.. True
# TC........G........GA.. True
# ..G...AA...C........C.. True
# ...T..A......TC.....C.. True
# ....GA.....T......T.C.. True
# GA..AA..............T.. True
# C.T..G.............CA.. True
# .G...A.A...........CA.. True
# .C..GAC............A... True
# T....TA............AA.. True
# GG.C..G............G... True
# ......CC...........GC.. True
# ....AA.AT.........T.... True
# T.....AA..........T.T.. True
# ....A..A..........G.... True
# .....A.A..........CGA.. True
# ..C..T.T.........T..A.. True
# ..T..T.T.........T..A.. True
# TG.....A.........T..T.. True
# .A..AA...........C..... True
# .A..AA..G........C..... True
# .G....G.T........A..A.. True
# TA..............C...... True
# .A...G..T.......G...... True
# T......A........G..AT.. True
# .A..A.A........G....T.. True
# .A..A.A........G....T.. True
# .A...G.A...G...A....... True
# G........C.C...G....... True
# G.C...A.....C..G....... True
# .A..C...T.....CC....... True
# .A.C...A.T......C...... True
# G..T......GT....C...... True
# ..GT......GT....C...... True
# ..GT......GT....C...... True
# ..GT......GT....C...... True
# ..GT......GT....C...... True
# .....T.T..GG....A...... True
# ..C..G.....G.T..A...... True
# ...GC.....G.....G...... True
# ....AG...T...T..G...... True
# T...A...C...A....A..... True
# .A..CG.......A...A..... True
# ......CA....A...GA..... True
# ..C..G.T.G.......T..... True
# T....A.T..T......T..... True
# ..GT.G....G......T..... True
# CA......C.A......C..... True
# G.C.......AT.....C..... True
# G.C.......AT.....C..... True
# ..T.A..T.....A...C..... True
# .C..G..A..A.......T.... True
# G..CG......G......T.... True
# CG..C......G......T.... True
# T....TG.....A.....T.... True
# .....G.T.TT.......C.... True
# C......A...C......C.... True
# .....GA.....GC....C.... True
# CA.........C..A...C.... True
# .....G..CCG.......G.... True
# ..C....C...C......G.... True
# .G..A..C...G......G.... True
# ..G..G....A...A...G.... True
# .A...G......G....TG.... True
# ....A...C....T...TG.... True
# ....AT....TC.......A... True
# ....GA......AT.....A... True
# .C...G.....C...C...A... True
# .G.....T..A......A.A... True
# GA.......TG........C... True
# .C.........G.......C... True
# ...T.A..T...C......C... True
# .GC...........C.G..C... True
# G....TG...A........G... True
# ...T.T.A.....T.....G... True
# .C..G.........A...TG... True
# .A......TC.G........A.. True
# C....T.......T......A.. True
# ..T..T.......T......A.. True
# T.C.........GT......A.. True
# .....T.C..T..A......A.. True
# ..C...A..T....C.....A.. True
# ..C...A..T....C.....A.. True
# T..T........C..G....A.. True
# ...G.A........CG....A.. True
# ...G.A........CG....A.. True
# ...G.A........CG....A.. True
# .....TG...G.......T.A.. True
# .C....G......C.....GA.. True
# ..GT.......G.......AA.. True
# G.G....C.....C......C.. True
# G.G....C.....C......C.. True
# .CT..........C..C...C.. True
# ......GT...T.....A..C.. True
# .A...T.......T.....AC.. True
# .C..G.........A....GC.. True
# ..T.C.C...A.........T.. True
# .....T.AT.A.........T.. True
# ....C.G...G.........T.. True
# ....C.G...G.........T.. True
# .G..G.C....T........T.. True
# .G..G.C....T........T.. True
# ........TG.G........T.. True
# T.G....C.....T......T.. True
# .....T..TG...T......T.. True
# .C....A.....CT......T.. True
# ...C.A..G....A......T.. True
# ...T...C...T.A......T.. True
# .C.....T..A....G....T.. True
# ...T...A...T.....T..T.. True
# ......GA......G..C..T.. True
# G.......C....C....G.T.. True
# ..G..G....A.......C.T.. True

# %%
from guido.genome import Genome, load_genome_from_file
from guido.locus import load_from_coordinates, load_from_gene

chromosome, start, end = "2R", 48714143, 48714653
AgamP4 = load_genome_from_file(guido_file='tests/data/AgamP4.12.guido')

l = load_from_coordinates(AgamP4, chromosome, start, end)
l.find_guides(min_flanking_length=20, selected_features={'exon'})

# %%
# def check_pam_mismatches(mismatches, pam):
# Out:
# ------
# CCGTGCGTCCAGAGCGTTCGAGG +
# ------
# GAGCAACGACCACCTGCTCTAGG +
# ------
# TGTTTTCTGTGTGTGTGTACAGG +
# ------
# TGTACAGGCCGTTTCTTGAACGG +
# ------
# GTACAGGCCGTTTCTTGAACGGG +
# ------
# TCGCCCTCCCCCCGAGACGCCGG +
# ------
# CGCACCGCACCAGTGCAGCTAGG +
# ------
# TCTGCTGCCCTTCTGTACCGTGG +
# ------
# TGCCCTTCTGTACCGTGGTGCGG +
# ------
# AAACACTAGTTTGAACTTATCGG +
# ------
# ATCGGCATCAGTTGCGCACGCGG +
# ------
# CACACCCACATACAAAGATACGG +
# ------
# AAAGATACGGACAGTTACAGTGG +
# ------
# TACGGACAGTTACAGTGGTGCGG +
# ------
# AAGTTTATCATCCACTCTGACGG +
# ------
# AGTTTATCATCCACTCTGACGGG +
# ------
# TTATCATCCACTCTGACGGGTGG +
# ------
# ATAGTAGATCCTAGAGCAGGTGG -
# ------
# TACATAGTAGATCCTAGAGCAGG -
# ------
# TGGTCGTCCCGTTCAAGAAACGG -
# ------
# GAGCAGCAAAAACAAAACAGTGG -
# ------
# AGGAAATTCTAGTGTTAAATCGG -
# ------
# GGCGTCTCGGGGGGAGGGCGAGG -
# ------
# CGTCCGGCGTCTCGGGGGGAGGG -
# ------
# GCGTCCGGCGTCTCGGGGGGAGG -
# ------
# GGTGCGTCCGGCGTCTCGGGGGG -
# ------
# CGGTGCGTCCGGCGTCTCGGGGG -
# ------
# GCGGTGCGTCCGGCGTCTCGGGG -
# ------
# TGCGGTGCGTCCGGCGTCTCGGG -
# ------
# GTGCGGTGCGTCCGGCGTCTCGG -
# ------
# CTGCACTGGTGCGGTGCGTCCGG -
# ------
# GCAGCCTAGCTGCACTGGTGCGG -
# ------
# GGTCGGCAGCCTAGCTGCACTGG -
# ------
# AGAAGGGCAGCAGAATGGGTCGG -
# ------
# GTACAGAAGGGCAGCAGAATGGG -
# ------
# GGTACAGAAGGGCAGCAGAATGG -
# ------
# AGCCGCACCACGGTACAGAAGGG -
# ------
# GAGCCGCACCACGGTACAGAAGG -
# ------
# GGAGCGAGAGAGCCGCACCACGG -
# ------
# TCAAACTAGTGTTTAAGGAGTGG -
# ------
# TAAGTTCAAACTAGTGTTTAAGG -
# ------
# TGGGTGTGTGTATGTGTGTTTGG -
# ....................... True
# ....................... True
# ------
# CTGTCCGTATCTTTGTATGTGGG -
# ------
# ACTGTCCGTATCTTTGTATGTGG -
# ------
# CGCAATACCACCCGTCAGAGTGG -
# ------
# TCTGAACATGTTTGATGGCGTGG -
# ------
# ATAATCTGAACATGTTTGATGG -

# %%
def isBowtieHitConsistent(bowtieLineColumns):
    '''
    Tells if the hit found show a set of mismatches, if any, consistent with the variable positions in the PAM
    ''' 
    # This generic version works for PAMs (5' or 3') where only the first position is an N
    # and the other position are not variables
    # NGG, NGA, NGCG, TTTN, NAAAAC
    # This is also fine for NRG because we search twice for NGG and NAG
    # The same for YTN (CTN, TTN)
    mismatches = bowtieLineColumns[7].split(',')
    posFirstMM = int(mismatches[0].split(":")[0])
    return posFirstMM >= (len('NGG') - 1)

out, err = run_bowtie('TTATCATCCACTCTGACGGGTGG')
for line in out.split('\n')[:]:
    columns = line.split('\t')
    if len(columns) > 1:
        if len(columns[7].split(',')) > 1:
            if isBowtieHitConsistent(columns):
                print(columns)
            else:
                print('x', columns)
        else:
            print('=', columns)
# Out:
# bin/bowtie/bowtie -p 1 --quiet -y -n 1 -l 13 -e 180 -a -x /Users/nace/imperial/guide_tool/guido/tests/data/AgamP4.12 -c TTATCATCCACTCTGACGGGTGG
# = ['0', '+', '2R', '48714553', 'TTATCATCCACTCTGACGGGTGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '']
# ['0', '-', '2R', '28714068', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '15:G>T,17:T>C,18:T>C,19:G>C,20:C>A,22:T>C']
# ['0', '-', '3L', '17339729', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '13:G>A,17:G>C,18:G>C,21:A>C,22:A>C']
# ['0', '-', '2L', '47386269', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '12:C>G,16:C>G,18:G>C,20:G>A,21:T>C,22:G>C']
# ['0', '-', '3L', '1582363', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '11:T>A,14:A>C,15:C>T,18:T>C,20:T>A,21:T>C']
# ['0', '-', '2L', '39403975', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '11:T>A,13:C>A,14:G>C,15:C>T,18:T>C']
# ['0', '-', '2R', '39013047', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '11:T>A,13:T>A,14:G>C,17:A>C,20:T>A,21:A>C']
# ['0', '-', 'X', '7246920', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '11:C>A,13:C>A,15:G>T,18:T>C,20:G>A,21:T>C']
# ['0', '-', '2R', '14390278', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '8:C>G,16:T>G,18:A>C,20:C>A']
# ['0', '-', '2R', '12374836', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '8:A>G,13:G>A,16:T>G,17:A>C,18:T>C,20:C>A']
# ['0', '-', '2L', '46566607', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '7:A>G,14:T>C,15:C>T,16:T>G,17:T>C,20:C>A']
# ['0', '+', '3R', '37929267', 'TTATCATCCACTCTGACGGGTGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '13:G>T,15:T>A,19:T>G,22:A>G']
# ['0', '+', 'X', '1644897', 'TTATCATCCACTCTGACGGGTGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '11:C>T,13:A>T,14:C>G,18:T>G,19:A>G,22:T>G']
# x ['0', '-', '2R', '51553744', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '1:G>A,14:G>C,15:C>T,16:C>G,17:A>C,18:T>C']
# ['0', '-', '3R', '17295196', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '2:A>T,14:G>C,15:A>T,17:G>C,18:G>C,20:G>A']
# ['0', '-', '3R', '9968089', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '3:C>A,13:C>A,16:T>G,19:G>C,20:C>A,22:A>C']
# ['0', '-', '3R', '3292794', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '3:G>A,14:A>C,17:G>C,19:T>C,20:T>A']
# ['0', '-', '2L', '36983211', 'CCACCCGTCAGAGTGGATGATAA', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '5:A>T,13:T>A,16:A>G,17:A>C,18:A>C,19:A>C']
# ['0', '+', '2R', '25568035', 'TTATCATCCACTCTGACGGGTGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '2:T>A,14:C>G,15:T>A,18:A>G,20:C>T,22:T>G']
# ['0', '+', '3R', '917386', 'TTATCATCCACTCTGACGGGTGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '2:G>A,13:G>T,14:A>G,17:T>G,18:C>G,21:A>G']
# ['0', '+', '3L', '4068146', 'TTATCATCCACTCTGACGGGTGG', 'IIIIIIIIIIIIIIIIIIIIIII', '0', '4:G>C,14:T>G,15:C>A,16:G>C,18:T>G,22:T>G']

# %%
iupac_code = {'R':'[AG]', 'Y':'[CT]', 'S':'[GC]', 'W':'[AT]', 'K':'[GT]', 'M':'[AC]', 'B':'[CGT]', 'D':'[AGT]', 'H':'[ACT]', 'V':'[ACG]', 'N':'[ACGTN]'}

def build_expression(seq):
    result = ''
    for c in seq:
        if c in iupac_code:
            result = result + iupac_code[c]
        else:
            result = result + c
            
    return result


def reverse_complement(sequence):
    rev_comp = []
    
    for idx in range(len(sequence) - 1, -1, -1):
        if sequence[idx] == 'A':
            rev_comp = rev_comp + ['T']
        elif sequence[idx] == 'C':
            rev_comp = rev_comp + ['G']
        elif sequence[idx] == 'G':
            rev_comp = rev_comp + ['C']
        elif sequence[idx] == 'T':
            rev_comp = rev_comp + ['A']
        else:
            rev_comp = rev_comp + ['N']
    return "".join(rev_comp)

class PAM(object):
    '''
    Generic class to define the different PAM types and the methods needed
    The seed for Bowtie will be always 5
    '''

    def __init__(self):
        '''
        Constructor
        '''
        self.coreAllowed = False  # By default a PAM is not compatible with the core region
        self.is5prime = False # Is the PAM at the 5' end, by default it is false
        self.PAM_str = self.__class__.__name__
        self.PAM_rev = reverse_complement(self.PAM_str)  # any ambiguous base is turned into N
        self.mismatchesPAM = self.PAM_rev.count('N')
        self.mismatchesInSeed = min(3,self.PAM_rev[0:5].count('N')) # Value for the -n parameter of Bowtie
        
    '''
    Received a list of sgRNAbindingSite objects and return a string with the
    fasta sequences formatted to perform the search of off-target sites with
    Bowtie
    '''
    def getSequencesforBowtie(self, sites):
        # By default all PAM are in the 3' end and the sequence is reversed to match the seed definition of Bowtie
        fasta = ""
        for candidate in sites:
            fasta = fasta + ">" + candidate.label + "\n"
            fasta = fasta + self.PAM_rev + reverse_complement(candidate.sequence[:-len(self.PAM_str)]) + "\n"
        return fasta
            
    def getBowtieOptions(self, coreMismatches, coreRange, totalMismatches):
        if not self.coreAllowed or coreMismatches == "NA" or coreRange == "NA":
            return ["-a", "--quiet", "-y", "-n" + str(self.mismatchesInSeed), "-l5", "-e" + str((totalMismatches + self.mismatchesPAM) * 30)]
        else:
            if (coreMismatches + self.mismatchesPAM)>3:
                raise ValueError('The value for the parameter coreMismatches is not valid: ' + str(coreMismatches))
            if coreMismatches > totalMismatches:
                raise ValueError('The value for coreMismatches cannot be greater than totalMismatches:' + str(coreMismatches) + ">" + str(totalMismatches))
            return ["-a", "--quiet", "-y", "-n" + str(coreMismatches + self.mismatchesPAM),
                    "-l" + str(coreRange + len(self.PAM_str)), "-e" + str((totalMismatches + self.mismatchesPAM) * 30)]
        
    def isBowtieHitConsistent(self, bowtieLineColumns):
        '''
        Tells if the hit found show a set of mismatches, if any, consistent with the variable positions in the PAM
        ''' 
        # This generic version works for PAMs (5' or 3') where only the first position is an N
        # and the other position are not variables
        # NGG, NGA, NGCG, TTTN, NAAAAC
        # This is also fine for NRG because we search twice for NGG and NAG
        # The same for YTN (CTN, TTN)
        mismatches = bowtieLineColumns[7].split(',')
        posFirstMM = int(mismatches[0].split(":")[0])
        return posFirstMM >= (len(self.PAM_str) - 1)

# %%
s = 'naceNGG'

s[:-3]
# Out:
# 'nace'
